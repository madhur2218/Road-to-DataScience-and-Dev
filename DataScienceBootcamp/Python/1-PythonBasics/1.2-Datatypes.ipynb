# %%
#Integer example
age = 34;
type(age)
# Out:
# int

# %%
#FLOATING DATA TYPE
height = 44.56;
print(height, type(height))
# Out:
# 44.56 <class 'float'>

# %%
#Boolean datatype
isTrue = True
type(isTrue)
# Out:
# bool

# %%
#String datatype
name = "MADHUR";
type(name)
# Out:
# str

# %%
a=10;
b=10;

print(a==b)
# Out:
# True

# %%
#common errors
result = "hello" + 34
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 #common errors
# ----> 2 result = "hello" + 34
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "hello" + str(34)   #type casting example
print(result)
# Out:
# hello34

# %%
#basic datatypes - int, float, string, boolean
