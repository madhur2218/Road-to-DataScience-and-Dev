# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\madhu\appdata\local\programs\python\python312\lib\site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\madhu\appdata\local\programs\python\python312\lib\site-packages (from pyspark) (0.10.9.7)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyspark.sql import SparkSession

# %%
#Creating a spark session

spark = SparkSession.builder.appName('Basics').getOrCreate()

# %%
df = spark.read.json("people.json")

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.columns
# Out:
# ['age', 'name']

# %%
df.describe().show()
# Out:
# +-------+------------------+-------+
# |summary|               age|   name|
# +-------+------------------+-------+
# |  count|                 2|      3|
# |   mean|              24.5|   NULL|
# | stddev|7.7781745930520225|   NULL|
# |    min|                19|   Andy|
# |    max|                30|Michael|
# +-------+------------------+-------+

# %%
from pyspark.sql.types import (StructField, StringType,
                                IntegerType,StructType)

# %%
data_schema =[StructField("age",IntegerType(),True), 
              StructField("name",StringType(),True)]

# %%
final_schema = StructType(fields=data_schema)

# %%
df= spark.read.json("people.json",schema=final_schema)

# %%
df.printSchema()
# Out:
# root
#  |-- age: integer (nullable = true)
#  |-- name: string (nullable = true)

# %%
df.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
type(df['age'])
# Out:
# pyspark.sql.column.Column

# %%
df.select('age').show()
# Out:
# +----+
# | age|
# +----+
# |NULL|
# |  30|
# |  19|
# +----+

# %%
type(df.select('name'))  #return type is a dataFrame
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.head(2)[1]
# Out:
# Row(age=30, name='Andy')

# %%
type(df.head(2)[1])
# Out:
# pyspark.sql.types.Row

# %%
df.select(["age","name"]).show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
df.withColumn("newAge", df["age"]*2).show()
# Out:
# +----+-------+------+
# | age|   name|newAge|
# +----+-------+------+
# |NULL|Michael|  NULL|
# |  30|   Andy|    60|
# |  19| Justin|    38|
# +----+-------+------+

# %%
df.withColumnRenamed("age","new_age").show()
# Out:
# +-------+-------+
# |new_age|   name|
# +-------+-------+
# |   NULL|Michael|
# |     30|   Andy|
# |     19| Justin|
# +-------+-------+

# %%
df.createOrReplaceTempView("people")

# %%
results = spark.sql("select * from people")
results.show()
# Out:
# +----+-------+
# | age|   name|
# +----+-------+
# |NULL|Michael|
# |  30|   Andy|
# |  19| Justin|
# +----+-------+

# %%
new_results= spark.sql("select * from people where age >10")
new_results.show()
# Out:
# +---+------+
# |age|  name|
# +---+------+
# | 30|  Andy|
# | 19|Justin|
# +---+------+
