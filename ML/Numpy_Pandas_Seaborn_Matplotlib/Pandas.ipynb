# %%
import numpy as np
import pandas as pd

# %%
np.array([1,2,"hello"])
# Out:
# array(['1', '2', 'hello'], dtype='<U11')

# %%
myindex = ['USA','Canada','Mexico']

# %%
mydata = [1776,1867,1821]

# %%
pd.Series(data=mydata,index=myindex)
# Out:
# USA       1776
# Canada    1867
# Mexico    1821
# dtype: int64

# %%
ran_data = np.random.randint(0,100,4)

type(ran_data)
# Out:
# numpy.ndarray

# %%
names = ['Andrew','Bobo','Claire','David']

type(names)
# Out:
# list

# %%
ages = pd.Series(data =ran_data, index = names)
ages.head(1)
# Out:
# Andrew    81
# dtype: int32

# %%
#Series from a dictionary 
ages = {"madhur": 2, "naman": 34, "ishant": 34}

pd.Series(ages)
# Out:
# madhur     2
# naman     34
# ishant    34
# dtype: int64

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
sales_q2['India']
# Out:
# 210

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q1 * 2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
sales_q2 / 100
# Out:
# Brazil    1.0
# China     5.0
# India     2.1
# USA       2.6
# dtype: float64

# %%
sales_q1+sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1.add(sales_q2, fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
#Pandas dataframes

np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myIndex = ['CA','NY','AZ','TX']

# %%
myColumns = ['Jan','Feb','Mar']

# %%
df = pd.DataFrame(data=mydata,index=myindex,columns=myColumns)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df = pd.DataFrame(data=mydata,index=myindex,columns=myColumns)
#       2 df
#
# File c:\Users\z004rr9n\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:758, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     747         mgr = dict_to_mgr(
#     748             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     749             # attribute "name"
#    (...)
#     755             copy=_copy,
#     756         )
#     757     else:
# --> 758         mgr = ndarray_to_mgr(
#     759             data,
#     760             index,
#     761             columns,
#     762             dtype=dtype,
#     763             copy=copy,
#     764             typ=manager,
#     765         )
# ...

# %%
pwd
# Out:
# 'd:\\Road-to-DataScience-and-Dev\\ML\\Numpy_Pandas_Seaborn_Matplotlib'

# %%
ls
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is C049-51C3
#
#  Directory of d:\Road-to-DataScience-and-Dev\ML\Numpy_Pandas_Seaborn_Matplotlib
#
# 07/06/2025  11:36 AM    <DIR>          .
# 07/05/2025  10:43 PM    <DIR>          ..
# 07/06/2025  11:36 AM            18,949 Numpy.ipynb
# 07/06/2025  12:17 PM             7,091 Pandas.ipynb
#                2 File(s)         26,040 bytes
#                2 Dir(s)  67,313,262,592 bytes free

# %%
df = pd.read_csv("tips.csv")
df.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.tail(4)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
len(df)
# Out:
# 244

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
type(df["total_bill"])
# Out:
# pandas.core.series.Series

# %%
type(df[["total_bill", "tip"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[["total_bill", "tip", "sex"]]
# Out:
#      total_bill   tip     sex
# 0         16.99  1.01  Female
# 1         10.34  1.66    Male
# 2         21.01  3.50    Male
# 3         23.68  3.31    Male
# 4         24.59  3.61  Female
# ..          ...   ...     ...
# 239       29.03  5.92    Male
# 240       27.18  2.00  Female
# 241       22.67  2.00    Male
# 242       17.82  1.75    Male
# 243       18.78  3.00  Female
#
# [244 rows x 3 columns]

# %%
df["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df["PercentageTip"] = 100* df["tip"]/df["total_bill"]
df["PercentageTip"]
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Name: PercentageTip, Length: 244, dtype: float64

# %%
df['price_per_person'] = df['total_bill'] / df['size']
df['price_per_person']
# Out:
# 0       8.495000
# 1       3.446667
# 2       7.003333
# 3      11.840000
# 4       6.147500
#          ...
# 239     9.676667
# 240    13.590000
# 241    11.335000
# 242     8.910000
# 243     9.390000
# Name: price_per_person, Length: 244, dtype: float64

# %%
help(np.round)
# Out:
# Help on function round_ in module numpy:
#
# round_(a, decimals=0, out=None)
#     Round an array to the given number of decimals.
#
#     See Also
#     --------
#     around : equivalent function; see for details.

# %%
df["price_per_person"] = np.round(df["price_per_person"],3)
df["price_per_person"]
# Out:
# 0       8.0
# 1       3.0
# 2       7.0
# 3      12.0
# 4       6.0
#        ...
# 239    10.0
# 240    14.0
# 241    11.0
# 242     9.0
# 243     9.0
# Name: price_per_person, Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.0
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.0
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              12.0
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.0
#
#            Payer Name         CC Number Payment ID  PercentageTip
# 0  Christy Cunningham  3560325168603410    Sun2959       5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608      16.054159
# 2      Travis Walters  6011812112971322    Sun4458      16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260      13.978041
# 4        Tonya Carter  4832732618637221    Sun2251      14.680765

# %%
df= df.drop("PercentageTip", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df= df.drop("PercentageTip", axis=1)
#
# File c:\Users\z004rr9n\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.0
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.0
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              12.0
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.0
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df =df.set_index("Payment ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15684\1545800290.py in ?()
# ----> 1 df =df.set_index("Payment ID")
#       2 df.head()
#
# c:\Users\z004rr9n\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Payment ID'] are in the columns"

# %%
df = df.reset_index()

# %%
df = df.set_index('Payment ID')

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# ...

# %%
type(df.loc["Sun5260"])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:2]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# Sun4608                  3.0      Douglas Tucker  4478071379779230

# %%
df.loc[['Sun2959','Thur672']]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# Thur672                  9.0     Michelle Hardin  3511451626698139

# %%
df.drop("Sun2959", axis = 0 ).head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                  3.0    Douglas Tucker  4478071379779230
# Sun4458                  7.0    Travis Walters  6011812112971322
# Sun5260                 12.0  Nathaniel Harris  4676137647685994
# Sun2251                  6.0      Tonya Carter  4832732618637221
# Sun9679                  6.0        Erik Smith   213140353657882

# %%
df[df["tip"]>1]
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# ...

# %%
bool_series = df['total_bill'] > 30

# %%
df[bool_series]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00    Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8903          38.01   3.00    Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Sun591           38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
df[df['total_bill']>30]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sun6686          35.26   5.00  Female     No   Sun  Dinner     4
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00    Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8903          38.01   3.00    Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00    Male    Yes  Thur   Lunch     2
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Sun591           38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
df[df["sex"] == "Male"]
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66  Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50  Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31  Male     No  Sun  Dinner     2
# Sun9679          25.29  4.71  Male     No  Sun  Dinner     4
# Sun5985           8.77  2.00  Male     No  Sun  Dinner     2
# ...                ...   ...   ...    ...  ...     ...   ...
# Sat5032          12.60  1.00  Male    Yes  Sat  Dinner     2
# Sat2929          32.83  1.17  Male    Yes  Sat  Dinner     2
# Sat2657          29.03  5.92  Male     No  Sat  Dinner     3
# Sat3880          22.67  2.00  Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75  Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun4608                  3.0      Douglas Tucker  4478071379779230
# Sun4458                  7.0      Travis Walters  6011812112971322
# ...

# %%
df_totalBillSex= df[(df["total_bill"]>30) | (df["sex"] == 'Male')]

# %%
df_totalBillSex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 164 entries, Sun4608 to Sat17
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        164 non-null    float64
#  1   tip               164 non-null    float64
#  2   sex               164 non-null    object
#  3   smoker            164 non-null    object
#  4   day               164 non-null    object
#  5   time              164 non-null    object
#  6   size              164 non-null    int64
#  7   price_per_person  164 non-null    float64
#  8   Payer Name        164 non-null    object
#  9   CC Number         164 non-null    int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 14.1+ KB

# %%
len(df_totalBillSex)
# Out:
# 164

# %%
df[(df["total_bill"]>40) & ~ (df["sex"] != 'Male')]
# Out:
#             total_bill    tip   sex smoker   day    time  size  \
# Payment ID
# Sat8139          48.27   6.73  Male     No   Sat  Dinner     4
# Fri9628          40.17   4.73  Male    Yes   Fri  Dinner     4
# Thur3621         41.19   5.00  Male     No  Thur   Lunch     5
# Sun7518          48.17   5.00  Male     No   Sun  Dinner     6
# Sat1954          50.81  10.00  Male    Yes   Sat  Dinner     3
# Sun2337          45.35   3.50  Male    Yes   Sun  Dinner     3
# Sun5140          40.55   3.00  Male    Yes   Sun  Dinner     2
# Sat4590          48.33   9.00  Male     No   Sat  Dinner     4
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat8139                 12.0      Brian Ortiz  6596453823950595
# Fri9628                 10.0    Aaron Bentley   180026611638690
# Thur3621                 8.0     Eric Andrews  4356531761046453
# Sun7518                  8.0    Ryan Gonzales  3523151482063321
# ...

# %%
# The Weekend
df[(df['day'] =='Sun') | (df['day']=='Sat')]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# ...

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.0  Christy Cunningham  3560325168603410
# Sun4608                  3.0      Douglas Tucker  4478071379779230
# Sun4458                  7.0      Travis Walters  6011812112971322
# Sun5260                 12.0    Nathaniel Harris  4676137647685994
# Sun2251                  6.0        Tonya Carter  4832732618637221

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, Sun2959 to Thur672
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 29.1+ KB
