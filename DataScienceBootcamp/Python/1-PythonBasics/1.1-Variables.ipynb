# %%
##Declaring a variable
a;
b;
sum;

# %%
#Declaring and assigning a variable
age =32;
height = 5.9;
name = "madhur";
isStudent = True;

#printning the variables
print("age: ",age);
print("height: ",height);
print("name: ",name);
print("isStudent: ",isStudent);
# Out:
# age:  32
# height:  5.9
# name:  madhur
# isStudent:  True

# %%
#Naming Conventions
#1. Use descriptive names
#2. Avoid reserved words
#3. Use camelCase for classes
#4. Use snake_case for variables
#5. Use PascalCase for classes


firstName = "John";
print(firstName);
# Out:
# John

# %%
# Invalid variable names
#2age=30
#first-name="Krish"
##@name="Krish"

# %%
#Python is dynamically typed and variable type is assigned at runtime

age = 32;
age="thirty two";

print(age);
# Out:
# thirty two

# %%
## Understnading Variable types
## Python is dynamically typed,type of a variable is determined at runtime
age=25 #int
height=6.1 #float
name="Krish" #str
is_student=True #bool

print(type(name))
# Out:
# <class 'str'>

# %%
type(height)
# Out:
# float
